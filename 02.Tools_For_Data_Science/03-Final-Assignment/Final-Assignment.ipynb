# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Name: **Prathik B Shetty**
#
# Desired Occupation: Data Scientist

# %% [markdown]
# *Interested in Data Science because it lets me make informed data driven decisions. In business Data Science can be used to get better insight on your customers*

# %% [markdown]
# ### Sample code to add two numbers

# %%
#Input from the user
a = int(input("First Number = "))
b = int(input("Second Number =  "))
#adding two numbers
Sum= a+b
#Printing the output on console
print(str(a)+" + "+str(b)+ " = "  + str(Sum))
# Out:
# First Number = 10
# Second Number =  20
# 10 + 20 = 30

# %% [markdown]
# <h3> Using HTML to Create Bulleted List, Numbered Lists and Horizontal Rule </h3><br>
# <hr>
# <h4>Bulleted List</h4>
# <ul>
#     <li>Item 1</li>
#     <li>Item 2</li>
#     <li>Item 3</li>
# </ul>
# <hr>
# <h4>Numbered List</h4>
# <ol>
#     <li>Order 1</li>
#     <li>Order 2</li>
#     <li>Order 3</li>
# <ol>
# <hr>
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQhyAybLMeUWCLXPNdEmMzPyF0sP7NJ6jya4w&usqp=CAU" alt="Watson Studio Image">
